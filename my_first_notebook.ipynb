# %% [markdown]
# Hardware refers to the physical components, like the CPU and RAM.
#
# Software includes the programs and applications that control these components.
